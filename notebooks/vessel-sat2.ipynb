# %%
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt, make_path_filter
from datetime import date

SUSER = ''
SPASSWORD = ''

sapi = SentinelAPI(SUSER, SPASSWORD, 'https://scihub.copernicus.eu/dhus/')

srd_wkt = """POLYGON((
    8.1298828125 38.5338022218,
    9.9371337891 38.5338022218,
    9.9371337891 41.522056887,
    8.1298828125 41.522056887,
    8.1298828125 38.5338022218
))"""

# %%
p = sapi.query(area=srd_wkt, date=('NOW-9DAYS', 'NOW'), area_relation="Intersects", platformname='Sentinel-2',
                     processinglevel='Level-2A')
print(p)
#sapi.to_geojson(p)
# Out:
# OrderedDict([('883a09af-e9f1-4809-8d07-97cd36fda740', {'title': 'S2B_MSIL2A_20230501T101559_N0509_R065_T32TNL_20230501T132325', 'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('883a09af-e9f1-4809-8d07-97cd36fda740')/$value", 'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('883a09af-e9f1-4809-8d07-97cd36fda740')/", 'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('883a09af-e9f1-4809-8d07-97cd36fda740')/Products('Quicklook')/$value", 'summary': 'Date: 2023-05-01T10:15:59.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 327.76 MB', 'ondemand': 'false', 'generationdate': datetime.datetime(2023, 5, 1, 13, 23, 25), 'beginposition': datetime.datetime(2023, 5, 1, 10, 15, 59, 24000), 'endposition': datetime.datetime(2023, 5, 1, 10, 15, 59, 24000), 'ingestiondate': datetime.datetime(2023, 5, 1, 15, 54, 48, 938000), 'orbitnumber': 32123, 'relativeorbitnumber': 65, 'illuminationazimuthangle': 154.182401357459, 'illuminationzenithangle': 2
# ...

# %%
import fnmatch

def test(a):
    npath = a['node_path']
    return fnmatch.fnmatch(npath, '*_TCI_10m.jp2') or fnmatch.fnmatch(npath, '*_SCL_20m.jp2')

path_filter = test #make_path_filter("*_TCI_10m.jp2")


for key, value in p.items():
    size = value['size']
    cov = value['cloudcoverpercentage']
    if cov > 30.:
        print ('skipping for cloud coverage', size, cov)
        continue
    print(size, cov)
    sapi.download(key, '/home/dakk/sattest/', nodefilter=path_filter)
# Out:
# skipping for cloud coverage 327.76 MB 89.663494
# skipping for cloud coverage 90.00 MB 100.0
# skipping for cloud coverage 616.10 MB 97.024167
# skipping for cloud coverage 514.62 MB 97.98665
# skipping for cloud coverage 876.40 MB 83.787805
# skipping for cloud coverage 948.09 MB 60.993361
# skipping for cloud coverage 964.94 MB 67.361969
# skipping for cloud coverage 377.67 MB 99.999684
# 425.29 MB 27.84887
# ...
# skipping for cloud coverage 953.00 MB 31.433839
# skipping for cloud coverage 800.13 MB 82.984698
# skipping for cloud coverage 542.55 MB 71.333653
# skipping for cloud coverage 781.78 MB 40.165833
# 831.51 MB 15.976977
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 17
#      15     continue
#      16 print(size, cov)
# ---> 17 sapi.download(key, '/home/dakk/sattest/', nodefilter=path_filter)
#
# ...
